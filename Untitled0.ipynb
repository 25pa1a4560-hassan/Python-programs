# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4560-hassan/Python-programs/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("enter value of x:"))
y=int(input("enter value of y:"))
print("sum of x,y is",x+y)
print("sub of x,y is",x-y)
print("mul of x,y is",x*y)
print("div of x,y is",x/y)
print("mod of x,y is",x%y)
print("floor div of x,y is",x//y)
print("exp of x,y is",x**y)
# Out:
# enter value of x:5
# enter value of y:3
# sum of x,y is 8
# sub of x,y is 2
# mul of x,y is 15
# div of x,y is 1.6666666666666667
# mod of x,y is 2
# floor div of x,y is 1
# exp of x,y is 125

# %%
x=int(input("enter value of x:"))
y=int(input("enter value of y:"))
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
# Out:
# enter value of x:4
# enter value of y:5
# False
# True
# False
# True
# False
# True

# %%
x=int(input("enter value of x:"))
y=int(input("enter value of y:"))
print(x and y)
print(x or y)
print(not y)
# Out:
# enter value of x:6
# enter value of y:6
# 6
# 6
# False
